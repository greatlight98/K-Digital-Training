# %%
import torch
from torch.autograd import Variable

from torch import nn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
torch.manual_seed(3)

# %% [markdown]
# # make data

# %%
x_train = torch.Tensor([[1],[2],[3]])
y_train = torch.Tensor([[1],[2],[3]])

x, y = Variable(x_train), Variable(y_train)

plt.scatter(x.data.numpy(), y.data.numpy())
plt.show()

# %% [markdown]
# # Naive Model

# %% [markdown]
# ## Define Linear model

# %%
x, y
# Out:
# (tensor([[1.],
#          [2.],
#          [3.]]),
#  tensor([[1.],
#          [2.],
#          [3.]]))

# %%
W = Variable(torch.rand(1,1))
W
# Out:
# tensor([[0.0043]])

# %%
x.mm(W)
# Out:
# tensor([[0.0043],
#         [0.0085],
#         [0.0128]])

# %% [markdown]
# ## Define cost function
#
# loss(x,y)=1/n∑|xi−yi|2loss(x,y)=1/n∑|xi−yi|2

# %%
cost_func = nn.MSELoss()

cost_func
# Out:
# MSELoss()

# %% [markdown]
# ## Training Linear Regression

# %%
plt.ion()       # interactive-on. 그림을 그때 그때 갱신. plt.ioff() 였으면 plt.show()에서 표현해줌

lr = 0.01

for step in range(300):
    prediction = x.mm(W)
    cost = cost_func(prediction, y)
    gradient = (prediction-y).view(-1).dot(x.view(-1)) / len(x)
    W -= lr * gradient
    
    if step % 10 == 0:
        plt.cla()
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), prediction.data.numpy(), 'r-')
        plt.title('step %d, cost=%.4f, w=%.4f,grad=%.4f' %  (step,cost.data, W.data[0], gradient.data))
        plt.show()
    
#     if step %10 == 0:
#         print(step, "going cost")
#         print(cost)
#         print((prediction-y).view(-1))
#         print((x.view(-1)))
#         print(gradient)
#         print(W)
plt.ioff()

# %%
x_test = Variable(torch.Tensor([[5]]))
y_test = x_test.mm(W)
y_test
# Out:
# tensor([[5.0000]])

# %% [markdown]
# # w/ nn Module

# %% [markdown]
# ## Define Linear Model

# %%
model  = nn.Linear(1, 1, bias=True)

print('model=', model)

model.weight, model.bias
# Out:
# model= Linear(in_features=1, out_features=1, bias=True)
# (Parameter containing:
#  tensor([[-0.7889]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.4283], requires_grad=True))

# %%
cost_func = nn.MSELoss()

# %%
for i in model.parameters():
    print(i)
# Out:
# Parameter containing:
# tensor([[-0.7889]], requires_grad=True)
# Parameter containing:
# tensor([-0.4283], requires_grad=True)

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ## Training w/ nn module

# %%
model(x)
# Out:
# tensor([[-1.2172],
#         [-2.0060],
#         [-2.7949]], grad_fn=<AddmmBackward>)

# %%
plt.ion()

for step in range(300):
    prediction = model(x)
    cost = cost_func(prediction, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 10 == 0:
        plt.cla()
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), prediction.data.numpy(), 'b--')
        plt.title('cost=%.4f, w=%.4f, b=%.4f' % (cost.data,model.weight.data[0][0],model.bias.data))
        plt.show()

plt.ioff()

# %%
x_test = Variable(torch.Tensor([[7]]))
y_test = model(x_test)

print('input : %.4f, output:%.4f' % (x_test.data[0][0], y_test.data[0][0]))    # [[7.]] 으로 생긴 data에서 값만 뽑음
# Out:
# input : 7.0000, output:6.6965

# %%
for step in range(300):
    prediction = model(x)
    cost = cost_func(prediction, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

x_test = Variable(torch.Tensor([[7]]))
y_test = model(x_test)

print('input : %.4f, output:%.4f' % (x_test.data[0][0], y_test.data[0][0]))
# Out:
# input : 7.0000, output:6.8526

# %%
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[0.9688]], requires_grad=True),
#  Parameter containing:
#  tensor([0.0709], requires_grad=True))

# %% [markdown]
# ###  Has "nn.MSELoss()"  Convex Cost Space?

# %%
W_val, cost_val = [], []

for i in range(-30, 51):
    W = i * 0.1
    model.weight.data.fill_(W)
    cost =  cost_func(model(x),y)
    
    W_val.append(W)
    cost_val.append(cost.data)

plt.plot(W_val, cost_val, 'ro')
plt.show()

# %% [markdown]
# # Multivariate Linear model

# %%
import numpy as np

# %% [markdown]
# ## make Data

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]                                                           # 값만 load
y_data = xy[:, [-1]]

print('shape: ', x_data.shape, '\nlength:', len(x_data), '\n', x_data )
print('shape: ', y_data.shape, '\nlength:', len(y_data), '\n', y_data )
# Out:
# shape:  (25, 3)
# length: 25
#  [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]]
# shape:  (25, 1)
# length: 25
#  [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
x, y = Variable(torch.from_numpy(x_data)), Variable(torch.from_numpy(y_data))   # Variable로 전환
x, y
# Out:
# (tensor([[ 73.,  80.,  75.],
#          [ 93.,  88.,  93.],
#          [ 89.,  91.,  90.],
#          [ 96.,  98., 100.],
#          [ 73.,  66.,  70.],
#          [ 53.,  46.,  55.],
#          [ 69.,  74.,  77.],
#          [ 47.,  56.,  60.],
#          [ 87.,  79.,  90.],
#          [ 79.,  70.,  88.],
#          [ 69.,  70.,  73.],
#          [ 70.,  65.,  74.],
#          [ 93.,  95.,  91.],
#          [ 79.,  80.,  73.],
#          [ 70.,  73.,  78.],
#          [ 93.,  89.,  96.],
#          [ 78.,  75.,  68.],
#          [ 81.,  90.,  93.],
#          [ 88.,  92.,  86.],
#          [ 78.,  83.,  77.],
#          [ 82.,  86.,  90.],
#          [ 86.,  82.,  89.],
#          [ 78.,  83.,  85.],
#          [ 76.,  83.,  71.],
#          [ 96.,  93.,  95.]]),
#  tensor([[152.],
#          [185.],
#          [180.],
#          [196.],
#          [142.],
#          [101.],
#          [149.],
#          [115.],
#          [175.],
#          [164.],
#          [141.],
#          [141.],
#          [184.],
#          [152.],
#          [148.],
#          [192.],
#          [147.],
#          [183.],
#          [177.],
#          [159.],
#          [177.],
#          [175.],
#          [175.],
#          [149.],
#          [192.]]))

# %% [markdown]
# ## make Model

# %%
mv_model = nn.Linear(3, 1, bias=True)   # Fully-connected, bias 포함

print(mv_model)
# Out:
# Linear(in_features=3, out_features=1, bias=True)

# %%
print('weigh : ', mv_model.weight)
print('bias   : ', mv_model.bias)
# Out:
# weigh :  Parameter containing:
# tensor([[-0.5462, -0.0328, -0.5079]], requires_grad=True)
# bias   :  Parameter containing:
# tensor([0.3139], requires_grad=True)

# %%
cost_func = nn.MSELoss()

optimizer = torch.optim.SGD(mv_model.parameters(), lr=1e-5)

# %% [markdown]
# ## Training Model

# %%
for step in range(2000):
    optimizer.zero_grad()
    
    prediction = mv_model(x)
    cost = cost_func(prediction, y)
    cost.backward()
    
    optimizer.step()
    
    if step % 50 == 0:
        print(step, "Cost: ", cost.data.numpy(), "\nPrediction:\n", prediction.data.t().numpy())
# Out:
# 0 Cost:  63235.75
# Prediction:
#  [[ -80.27773  -100.60726   -96.996895 -106.12925   -77.27918   -58.080135
#    -78.91204   -57.67022   -95.51112   -89.83046   -76.7492    -77.639465
#    -99.82084   -82.53922   -79.93342  -102.16385   -79.28944   -94.11811
#    -94.45171   -84.123055  -93.00944   -94.55529   -88.18653   -79.98301
#   -103.4257  ]]
# 50 Cost:  18.11426
# Prediction:
#  [[156.05579 183.55751 182.9336  198.77402 139.43988 101.76946 149.3429
#   111.57456 170.13354 156.31465 143.15779 139.25809 189.34947 157.79968
#   149.39186 186.222   149.59128 179.80757 181.2073  162.5206  174.65862
#   172.05891 166.99348 158.21191 191.04263]]
# 100 Cost:  17.597153
# Prediction:
#  [[155.98497 183.58311 182.89873 198.7732  139.45627 101.85179 149.36647
#   111.62254 170.22855 156.49464 143.17534 139.33849 189.27736 157.69406
#   149.43619 186.27318 149.47993 179.83368 181.1156  162.4333  174.68892
#   172.11212 167.0024  158.05605 191.0343 ]]
# 150 Cost:  17.102472
# Prediction:
#  [[155.91576  183.60812  182.86464  198.77242  139.47223  101.93227
#   149.38956  111.669586 170.32143  156.67068  143.19252  139.41708
#   189.20683  157.59073  149.47957  186.3232   149.37097  179.85928
#   181.02594  162.34796  174.71861  172.16412  167.01118  157.90361
#   191.02612 ]]
# 200 Cost:  16.629223
# Prediction:
#  [[155.8481  183.63255 182.8313  198.77168 139.48778 102.01093 149.41222
#   111.7157  170.41222 156.84283 143.20934 139.49394 189.13785 157.48964
#   149.52205 186.3721  149.2643  179.88445 180.93822 162.26448 174.7477
#   172.21498 167.0198  157.75453 191.01807]]
# 250 Cost:  16.17648
# Prediction:
#  [[155.78198 183.65639 182.7987  198.77097 139.50291 102.08783 149.43442
#   111.76089 170.50096 157.01118 143.22578 139.5691  189.07036 157.39073
#   149.56364 186.4199  149.15991 179.90913 180.85243 162.18285 174.7762
#   172.2647  167.02829 157.60872 191.01018]]
# 300 Cost:  15.743369
# Prediction:
#  [[155.71733 183.67966 182.76682 198.7703  139.51764 102.163   149.45619
#   111.8052  170.5877  157.1758  143.2419  139.6426  189.00433 157.29395
#   149.60435 186.46664 149.05774 179.93338 180.76854 162.10303 174.80412
#   172.31328 167.03665 157.46614 191.00241]]
# 350 Cost:  15.329031
# Prediction:
#  [[155.65416 183.70238 182.73563 198.7696  139.532   102.23647 149.47752
#   112.74879 172.36285 160.56313 143.57762 141.15112 187.63945 155.28842
#   150.45618 187.42307 146.92892 180.46045 179.03851 160.46048 175.39322
#   173.30841 167.22287 154.52747 190.8315 ]]
# 1750 Cost:  8.825632
# Prediction:
#  [[154.36214 184.15814 182.09311 198.7603  139.80878 103.73983 149.93312
#   112.77384 172.40761 160.64917 143.5863  141.18932 187.60457 155.237
#   150.47829 187.44719 146.87395 180.47481 178.99443 160.41875 175.40869
#   173.33351 167.2281  154.45267 190.82677]]
# 1800 Cost:  8.710813
# Prediction:
#  [[154.32957 184.1693  182.07674 198.76018 139.81516 103.77772 149.94524
#   112.79841 172.45131 160.73328 143.59477 141.22664 187.57042 155.18666
#   150.49992 187.47073 146.82008 180.48889 178.95131 160.37793 175.42383
#   173.35805 167.23322 154.3795  190.8221 ]]
# 1850 Cost:  8.600923
# Prediction:
#  [[154.29779  184.1802   182.06076  198.76012  139.82138  103.81474
#   149.95715  112.822525 172.49408  160.81557  143.6031   141.26317
#   187.53703  155.13744  150.52115  187.49379  146.76741  180.50278
#   178.90918  160.33804  175.43869  173.38205  167.2383   154.30795
#   190.81755 ]]
# 1900 Cost:  8.495801
# Prediction:
#  [[154.26671 184.19086 182.04515 198.76006 139.82741 103.85093 149.96883
#   112.84617 172.53586 160.89601 143.61124 141.29886 187.50438 155.08925
#   150.54193 187.51631 146.71584 180.5164  178.86797 160.29904 175.45326
#   173.4055  167.24329 154.23799 190.81306]]
# 1950 Cost:  8.395222
# Prediction:
#  [[154.23634  184.20122  182.02985  198.75998  139.83327  103.886314
#   149.98029  112.86938  172.57668  160.97469  143.61922  141.33376
#   187.47241  155.0421   150.56227  187.53831  146.66531  180.52977
#   178.82762  160.2609   175.46754  173.42842  167.24818  154.16957
#   190.80864 ]]

# %%
mv_model.state_dict()
# Out:
# OrderedDict([('weight', tensor([[0.4244, 0.7125, 0.8787]])),
#              ('bias', tensor([0.3253]))])

# %% [markdown]
# ## test

# %%
print("Model score : ",mv_model(Variable(torch.Tensor([[73,80,75]]))).data.numpy())
print("Real score : 73,80,75,152")
# Out:
# Model score :  [[154.20667]]
# Real score : 73,80,75,152

# %%
error_list = []
for i,real_y in enumerate(y):
    error = (mv_model((x[i])).data.numpy() - real_y.data.numpy())
    error_list.append(np.absolute(error))

for err in error_list:
    print(err)

print("sum error : ",sum(error_list))
print("avg error : ",sum(error_list)/len(y))
# Out:
# [2.206665]
# [0.7886658]
# [2.0148926]
# [2.7599335]
# [2.1610565]
# [2.920868]
# [0.9915314]
# [2.1078796]
# [2.3834229]
# [2.9483948]
# [2.6270142]
# [0.3678589]
# [3.441162]
# [2.9959717]
# [2.582199]
# [4.4401703]
# [0.38412476]
# [2.457077]
# [1.7881927]
# [1.223587]
# [1.5184784]
# [1.5491943]
# [7.746994]
# [5.102646]
# [1.1957092]
# sum error :  [60.70369]
# avg error :  [2.4281476]
