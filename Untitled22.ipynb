# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df = titanic.loc[:, ['age','sex', 'class', 'fare', 'survived']]

# %%
df
# Out:
#       age     sex   class     fare  survived
# 0    22.0    male   Third   7.2500         0
# 1    38.0  female   First  71.2833         1
# 2    26.0  female   Third   7.9250         1
# 3    35.0  female   First  53.1000         1
# 4    35.0    male   Third   8.0500         0
# ..    ...     ...     ...      ...       ...
# 886  27.0    male  Second  13.0000         0
# 887  19.0  female   First  30.0000         1
# 888   NaN  female   Third  23.4500         0
# 889  26.0    male   First  30.0000         1
# 890  32.0    male   Third   7.7500         0
#
# [891 rows x 5 columns]

# %%
group = df.groupby(['age'])

# %%
age_mean = grouped.age.mean()

# %%
age_std = grouped.age.std()

# %%
for key, group in grouped.age:
    group_zscore = (group - age_mean.loc[key])/age_std.loc[key]
    print(key)
    print(group_zscore)
    print('\n')
# Out:
# 0.42
# 803   NaN
# Name: age, dtype: float64
#
#
# 0.67
# 755   NaN
# Name: age, dtype: float64
#
#
# 0.75
# 469   NaN
# 644   NaN
# Name: age, dtype: float64
#
#
# 0.83
# 78    NaN
# 831   NaN
# Name: age, dtype: float64
#
#
# 0.92
# 305   NaN
# Name: age, dtype: float64
#
#
# 1.0
# 164   NaN
# 172   NaN
# 183   NaN
# 381   NaN
# 386   NaN
# 788   NaN
# 827   NaN
# Name: age, dtype: float64
#
#
# 2.0
# 7     NaN
# 16    NaN
# 119   NaN
# 205   NaN
# 297   NaN
# 340   NaN
# 479   NaN
# 530   NaN
# 642   NaN
# 824   NaN
# Name: age, dtype: float64
#
#
# 3.0
# 43    NaN
# 193   NaN
# 261   NaN
# 348   NaN
# 374   NaN
# 407   NaN
# Name: age, dtype: float64
#
#
# 4.0
# 10    NaN
# 63    NaN
# 171   NaN
# 184   NaN
# 445   NaN
# 618   NaN
# 691   NaN
# 750   NaN
# 850   NaN
# 869   NaN
# Name: age, dtype: float64
#
#
# 5.0
# 58    NaN
# 233   NaN
# 448   NaN
# 777   NaN
# Name: age, dtype: float64
#
#
# 6.0
# 720   NaN
# 751   NaN
# 813   NaN
# Name: age, dtype: float64
#
#
# 7.0
# 50    NaN
# 278   NaN
# 535   NaN
# Name: age, dtype: float64
#
#
# 8.0
# 24    NaN
# 237   NaN
# 549   NaN
# 787   NaN
# Name: age, dtype: float64
#
#
# 9.0
# 147   NaN
# 165   NaN
# 182   NaN
# 480   NaN
# 489   NaN
# 541   NaN
# 634   NaN
# 852   NaN
# Name: age, dtype: float64
#
#
# 10.0
# 419   NaN
# 819   NaN
# Name: age, dtype: float64
#
#
# 11.0
# 59    NaN
# 542   NaN
# 731   NaN
# 802   NaN
# Name: age, dtype: float64
#
#
# 12.0
# 125   NaN
# Name: age, dtype: float64
#
#
# 13.0
# 446   NaN
# 780   NaN
# Name: age, dtype: float64
#
#
# 14.0
# 9     NaN
# 14    NaN
# 39    NaN
# 435   NaN
# 683   NaN
# 686   NaN
# Name: age, dtype: float64
#
#
# 14.5
# 111   NaN
# Name: age, dtype: float64
#
#
# 15.0
# 22    NaN
# 352   NaN
# 689   NaN
# 830   NaN
# 875   NaN
# Name: age, dtype: float64
#
#
# 16.0
# 71    NaN
# 86    NaN
# 138   NaN
# 156   NaN
# 208   NaN
# 220   NaN
# 266   NaN
# 282   NaN
# 329   NaN
# 333   NaN
# 504   NaN
# 574   NaN
# 746   NaN
# 764   NaN
# 791   NaN
# 841   NaN
# 853   NaN
# Name: age, dtype: float64
#
#
# 17.0
# 68    NaN
# 84    NaN
# 114   NaN
# 163   NaN
# 307   NaN
# 389   NaN
# 433   NaN
# 500   NaN
# 532   NaN
# 550   NaN
# 721   NaN
# 781   NaN
# 844   NaN
# Name: age, dtype: float64
#
#
# 18.0
# 38    NaN
# 49    NaN
# 144   NaN
# 175   NaN
# 204   NaN
# 228   NaN
# 311   NaN
# 371   NaN
# 385   NaN
# 417   NaN
# 424   NaN
# 505   NaN
# 585   NaN
# 651   NaN
# 654   NaN
# 675   NaN
# 677   NaN
# 688   NaN
# 700   NaN
# 702   NaN
# 757   NaN
# 775   NaN
# 786   NaN
# 807   NaN
# 834   NaN
# 855   NaN
# Name: age, dtype: float64
#
#
# 19.0
# 27    NaN
# 44    NaN
# 67    NaN
# 136   NaN
# 143   NaN
# 145   NaN
# 191   NaN
# 192   NaN
# 226   NaN
# 238   NaN
# 283   NaN
# 291   NaN
# 302   NaN
# 372   NaN
# 379   NaN
# 427   NaN
# 546   NaN
# 566   NaN
# 575   NaN
# 646   NaN
# 687   NaN
# 715   NaN
# 748   NaN
# 877   NaN
# 887   NaN
# Name: age, dtype: float64
#
#
# 20.0
# 12    NaN
# 91    NaN
# 113   NaN
# 131   NaN
# 378   NaN
# 404   NaN
# 441   NaN
# 622   NaN
# 640   NaN
# 664   NaN
# 682   NaN
# 725   NaN
# 762   NaN
# 840   NaN
# 876   NaN
# Name: age, dtype: float64
#
#
# 20.5
# 227   NaN
# Name: age, dtype: float64
#
#
# 21.0
# 37    NaN
# 51    NaN
# 56    NaN
# 72    NaN
# 102   NaN
# 106   NaN
# 115   NaN
# 120   NaN
# 173   NaN
# 391   NaN
# 402   NaN
# 408   NaN
# 421   NaN
# 436   NaN
# 491   NaN
# 494   NaN
# 501   NaN
# 623   NaN
# 624   NaN
# 627   NaN
# 652   NaN
# 742   NaN
# 836   NaN
# 861   NaN
# Name: age, dtype: float64
#
#
# 22.0
# 0     NaN
# 60    NaN
# 80    NaN
# 112   NaN
# 141   NaN
# 151   NaN
# 212   NaN
# 225   NaN
# 243   NaN
# 287   NaN
# 289   NaN
# 320   NaN
# 323   NaN
# 356   NaN
# 373   NaN
# 376   NaN
# 395   NaN
# 474   NaN
# 478   NaN
# 521   NaN
# 539   NaN
# 553   NaN
# 554   NaN
# 588   NaN
# 608   NaN
# 708   NaN
# 882   NaN
# Name: age, dtype: float64
#
#
# 23.0
# 88    NaN
# 97    NaN
# 135   NaN
# 350   NaN
# 393   NaN
# 398   NaN
# 473   NaN
# 529   NaN
# 649   NaN
# 658   NaN
# 733   NaN
# 734   NaN
# 753   NaN
# 816   NaN
# 833   NaN
# Name: age, dtype: float64
#
#
# 23.5
# 296   NaN
# Name: age, dtype: float64
#
#
# 24.0
# 89    NaN
# 118   NaN
# 127   NaN
# 139   NaN
# 142   NaN
# 199   NaN
# 210   NaN
# 234   NaN
# 247   NaN
# 293   NaN
# 294   NaN
# 310   NaN
# 316   NaN
# 341   NaN
# 345   NaN
# 369   NaN
# 394   NaN
# 437   NaN
# 499   NaN
# 514   NaN
# 565   NaN
# 600   NaN
# 615   NaN
# 641   NaN
# 655   NaN
# 710   NaN
# 743   NaN
# 770   NaN
# 858   NaN
# 864   NaN
# Name: age, dtype: float64
#
#
# 24.5
# 676   NaN
# Name: age, dtype: float64
#
#
# 25.0
# 75    NaN
# 134   NaN
# 246   NaN
# 267   NaN
# 271   NaN
# 343   NaN
# 353   NaN
# 370   NaN
# 442   NaN
# 484   NaN
# 498   NaN
# 580   NaN
# 666   NaN
# 685   NaN
# 693   NaN
# 703   NaN
# 728   NaN
# 729   NaN
# 784   NaN
# 785   NaN
# 794   NaN
# 880   NaN
# 884   NaN
# Name: age, dtype: float64
#
#
# 26.0
# 2     NaN
# 69    NaN
# 73    NaN
# 93    NaN
# 162   NaN
# 207   NaN
# 290   NaN
# 312   NaN
# 315   NaN
# 401   NaN
# 509   NaN
# 617   NaN
# 619   NaN
# 628   NaN
# 704   NaN
# 810   NaN
# 870   NaN
# 889   NaN
# Name: age, dtype: float64
#
#
# 27.0
# 8     NaN
# 41    NaN
# 146   NaN
# 216   NaN
# 221   NaN
# 321   NaN
# 377   NaN
# 551   NaN
# 607   NaN
# 620   NaN
# 681   NaN
# 717   NaN
# 724   NaN
# 804   NaN
# 821   NaN
# 823   NaN
# 866   NaN
# 886   NaN
# Name: age, dtype: float64
#
#
# 28.0
# 23    NaN
# 34    NaN
# 83    NaN
# 100   NaN
# 105   NaN
# 169   NaN
# 200   NaN
# 281   NaN
# 313   NaN
# 342   NaN
# 355   NaN
# 392   NaN
# 399   NaN
# 403   NaN
# 423   NaN
# 426   NaN
# 430   NaN
# 443   NaN
# 508   NaN
# 562   NaN
# 635   NaN
# 756   NaN
# 848   NaN
# 874   NaN
# 883   NaN
# Name: age, dtype: float64
#
#
# 28.5
# 57    NaN
# 735   NaN
# Name: age, dtype: float64
#
#
# 29.0
# 53    NaN
# 66    NaN
# 81    NaN
# 90    NaN
# 117   NaN
# 133   NaN
# 231   NaN
# 242   NaN
# 251   NaN
# 255   NaN
# 336   NaN
# 361   NaN
# 422   NaN
# 455   NaN
# 477   NaN
# 510   NaN
# 567   NaN
# 713   NaN
# 730   NaN
# 782   NaN
# Name: age, dtype: float64
#
#
# 30.0
# 79    NaN
# 157   NaN
# 178   NaN
# 213   NaN
# 219   NaN
# 244   NaN
# 253   NaN
# 257   NaN
# 286   NaN
# 308   NaN
# 309   NaN
# 322   NaN
# 365   NaN
# 418   NaN
# 452   NaN
# 488   NaN
# 520   NaN
# 534   NaN
# 537   NaN
# 606   NaN
# 726   NaN
# 747   NaN
# 798   NaN
# 799   NaN
# 842   NaN
# Name: age, dtype: float64
#
#
# 30.5
# 767   NaN
# 814   NaN
# Name: age, dtype: float64
#
#
# 31.0
# 18    NaN
# 215   NaN
# 318   NaN
# 328   NaN
# 396   NaN
# 439   NaN
# 637   NaN
# 671   NaN
# 673   NaN
# 690   NaN
# 744   NaN
# 749   NaN
# 797   NaN
# 801   NaN
# 805   NaN
# 817   NaN
# 867   NaN
# Name: age, dtype: float64
#
#
# 32.0
# 70    NaN
# 74    NaN
# 190   NaN
# 206   NaN
# 218   NaN
# 382   NaN
# 429   NaN
# 519   NaN
# 543   NaN
# 569   NaN
# 579   NaN
# 632   NaN
# 636   NaN
# 657   NaN
# 665   NaN
# 769   NaN
# 838   NaN
# 890   NaN
# Name: age, dtype: float64
#
#
# 32.5
# 122   NaN
# 123   NaN
# Name: age, dtype: float64
#
#
# 33.0
# 85    NaN
# 103   NaN
# 130   NaN
# 239   NaN
# 285   NaN
# 412   NaN
# 472   NaN
# 506   NaN
# 548   NaN
# 719   NaN
# 752   NaN
# 759   NaN
# 809   NaN
# 872   NaN
# 881   NaN
# Name: age, dtype: float64
#
#
# 34.0
# 21    NaN
# 98    NaN
# 99    NaN
# 202   NaN
# 405   NaN
# 416   NaN
# 447   NaN
# 461   NaN
# 476   NaN
# 516   NaN
# 576   NaN
# 616   NaN
# 722   NaN
# 758   NaN
# 800   NaN
# Name: age, dtype: float64
#
#
# 34.5
# 843   NaN
# Name: age, dtype: float64
#
#
# 35.0
# 3     NaN
# 4     NaN
# 20    NaN
# 211   NaN
# 230   NaN
# 258   NaN
# 269   NaN
# 279   NaN
# 363   NaN
# 383   NaN
# 486   NaN
# 590   NaN
# 604   NaN
# 614   NaN
# 701   NaN
# 737   NaN
# 812   NaN
# 847   NaN
# Name: age, dtype: float64
#
#
# 36.0
# 179   NaN
# 189   NaN
# 265   NaN
# 292   NaN
# 325   NaN
# 327   NaN
# 344   NaN
# 387   NaN
# 390   NaN
# 450   NaN
# 512   NaN
# 518   NaN
# 540   NaN
# 559   NaN
# 572   NaN
# 583   NaN
# 595   NaN
# 605   NaN
# 663   NaN
# 679   NaN
# 741   NaN
# 763   NaN
# Name: age, dtype: float64
#
#
# 36.5
# 148   NaN
# Name: age, dtype: float64
#
#
# 37.0
# 104   NaN
# 137   NaN
# 248   NaN
# 273   NaN
# 503   NaN
# 594   NaN
# Name: age, dtype: float64
#
#
# 38.0
# 1     NaN
# 25    NaN
# 61    NaN
# 108   NaN
# 224   NaN
# 332   NaN
# 357   NaN
# 465   NaN
# 471   NaN
# 716   NaN
# 822   NaN
# Name: age, dtype: float64
#
#
# 39.0
# 13    NaN
# 400   NaN
# 528   NaN
# 558   NaN
# 577   NaN
# 581   NaN
# 610   NaN
# 705   NaN
# 795   NaN
# 806   NaN
# 808   NaN
# 811   NaN
# 835   NaN
# 885   NaN
# Name: age, dtype: float64
#
#
# 40.0
# 30    NaN
# 40    NaN
# 161   NaN
# 188   NaN
# 209   NaN
# 263   NaN
# 319   NaN
# 346   NaN
# 360   NaN
# 561   NaN
# 609   NaN
# 661   NaN
# 670   NaN
# Name: age, dtype: float64
#
#
# 40.5
# 153   NaN
# 525   NaN
# Name: age, dtype: float64
#
#
# 41.0
# 254   NaN
# 272   NaN
# 337   NaN
# 638   NaN
# 761   NaN
# 860   NaN
# Name: age, dtype: float64
#
#
# 42.0
# 35    NaN
# 149   NaN
# 197   NaN
# 217   NaN
# 288   NaN
# 349   NaN
# 380   NaN
# 432   NaN
# 621   NaN
# 699   NaN
# 707   NaN
# 845   NaN
# 865   NaN
# Name: age, dtype: float64
#
#
# 43.0
# 314   NaN
# 668   NaN
# 678   NaN
# 779   NaN
# 818   NaN
# Name: age, dtype: float64
#
#
# 44.0
# 160   NaN
# 194   NaN
# 236   NaN
# 245   NaN
# 414   NaN
# 523   NaN
# 603   NaN
# 696   NaN
# 854   NaN
# Name: age, dtype: float64
#
#
# 45.0
# 62    NaN
# 129   NaN
# 167   NaN
# 187   NaN
# 276   NaN
# 338   NaN
# 339   NaN
# 362   NaN
# 440   NaN
# 536   NaN
# 706   NaN
# 856   NaN
# Name: age, dtype: float64
#
#
# 45.5
# 203   NaN
# 331   NaN
# Name: age, dtype: float64
#
#
# 46.0
# 92    NaN
# 397   NaN
# 789   NaN
# Name: age, dtype: float64
#
#
# 47.0
# 110   NaN
# 132   NaN
# 462   NaN
# 515   NaN
# 586   NaN
# 592   NaN
# 662   NaN
# 871   NaN
# 873   NaN
# Name: age, dtype: float64
#
#
# 48.0
# 460   NaN
# 463   NaN
# 556   NaN
# 645   NaN
# 712   NaN
# 736   NaN
# 754   NaN
# 771   NaN
# 862   NaN
# Name: age, dtype: float64
#
#
# 49.0
# 52    NaN
# 453   NaN
# 597   NaN
# 599   NaN
# 698   NaN
# 796   NaN
# Name: age, dtype: float64
#
#
# 50.0
# 177   NaN
# 259   NaN
# 299   NaN
# 434   NaN
# 458   NaN
# 482   NaN
# 526   NaN
# 544   NaN
# 660   NaN
# 723   NaN
# Name: age, dtype: float64
#
#
# 51.0
# 150   NaN
# 155   NaN
# 222   NaN
# 406   NaN
# 631   NaN
# 765   NaN
# 857   NaN
# Name: age, dtype: float64
#
#
# 52.0
# 262   NaN
# 449   NaN
# 591   NaN
# 695   NaN
# 714   NaN
# 820   NaN
# Name: age, dtype: float64
#
#
# 53.0
# 571   NaN
# Name: age, dtype: float64
#
#
# 54.0
# 6     NaN
# 124   NaN
# 249   NaN
# 317   NaN
# 496   NaN
# 513   NaN
# 582   NaN
# 774   NaN
# Name: age, dtype: float64
#
#
# 55.0
# 15    NaN
# 492   NaN
# Name: age, dtype: float64
#
#
# 55.5
# 152   NaN
# Name: age, dtype: float64
#
#
# 56.0
# 174   NaN
# 467   NaN
# 647   NaN
# 879   NaN
# Name: age, dtype: float64
#
#
# 57.0
# 626   NaN
# 772   NaN
# Name: age, dtype: float64
#
#
# 58.0
# 11    NaN
# 195   NaN
# 268   NaN
# 487   NaN
# 659   NaN
# Name: age, dtype: float64
#
#
# 59.0
# 94    NaN
# 232   NaN
# Name: age, dtype: float64
#
#
# 60.0
# 366   NaN
# 587   NaN
# 684   NaN
# 694   NaN
# Name: age, dtype: float64
#
#
# 61.0
# 170   NaN
# 326   NaN
# 625   NaN
# Name: age, dtype: float64
#
#
# 62.0
# 252   NaN
# 555   NaN
# 570   NaN
# 829   NaN
# Name: age, dtype: float64
#
#
# 63.0
# 275   NaN
# 483   NaN
# Name: age, dtype: float64
#
#
# 64.0
# 438   NaN
# 545   NaN
# Name: age, dtype: float64
#
#
# 65.0
# 54    NaN
# 280   NaN
# 456   NaN
# Name: age, dtype: float64
#
#
# 66.0
# 33   NaN
# Name: age, dtype: float64
#
#
# 70.0
# 672   NaN
# 745   NaN
# Name: age, dtype: float64
#
#
# 70.5
# 116   NaN
# Name: age, dtype: float64
#
#
# 71.0
# 96    NaN
# 493   NaN
# Name: age, dtype: float64
#
#
# 74.0
# 851   NaN
# Name: age, dtype: float64
#
#
# 80.0
# 630   NaN
# Name: age, dtype: float64

# %%
def z_score(x):
    return(x-x.mean())/x.std

# %%
grouped.age.transform(z_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a48dfa7ed3a6> in <module>
# ----> 1 grouped.age.transform(z_score)
#
# NameError: name 'z_score' is not defined

# %%
transformed_age = grouped.age.transform(z_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fdcd3e357d4c> in <module>
# ----> 1 transformed_age = grouped.age.transform(z_score)
#
# NameError: name 'z_score' is not defined

# %%
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','sex', 'class', 'fare', 'survived']]
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
grouped=df.groupby(['class'])

# %%
grouped.apply(lambda x : x.describe()) #그룹별 요약통계량 산출
# Out:
#                      age        fare    survived
# class
# First  count  186.000000  216.000000  216.000000
#        mean    38.233441   84.154687    0.629630
#        std     14.802856   78.380373    0.484026
#        min      0.920000    0.000000    0.000000
#        25%     27.000000   30.923950    0.000000
#        50%     37.000000   60.287500    1.000000
#        75%     49.000000   93.500000    1.000000
#        max     80.000000  512.329200    1.000000
# Second count  173.000000  184.000000  184.000000
#        mean    29.877630   20.662183    0.472826
#        std     14.001077   13.417399    0.500623
#        min      0.670000    0.000000    0.000000
#        25%     23.000000   13.000000    0.000000
#        50%     29.000000   14.250000    0.000000
#        75%     36.000000   26.000000    1.000000
#        max     70.000000   73.500000    1.000000
# Third  count  355.000000  491.000000  491.000000
#        mean    25.140620   13.675550    0.242363
#        std     12.495398   11.778142    0.428949
#        min      0.420000    0.000000    0.000000
#        25%     18.000000    7.750000    0.000000
#        50%     24.000000    8.050000    0.000000
#        75%     32.000000   15.500000    0.000000
#        max     74.000000   69.550000    1.000000

# %%
def z_score(x):
    return (x-x.mean())/x.std()

grouped.age.apply(z_score)
# Out:
# 0     -0.251342
# 1     -0.015770
# 2      0.068776
# 3     -0.218434
# 4      0.789041
#          ...
# 886   -0.205529
# 887   -1.299306
# 888         NaN
# 889   -0.826424
# 890    0.548953
# Name: age, Length: 891, dtype: float64

# %%
age_filter = grouped.apply(lambda x : x.age.mean()>30)

# %%
for i in age_filter.index:
    if age_filter[i]==True:
        age_filter_df = grouped.get_group(i)
        print(age_filter_df.head())
        print('\n')
# Out:
#      age     sex  class     fare  survived
# 1   38.0  female  First  71.2833         1
# 3   35.0  female  First  53.1000         1
# 6   54.0    male  First  51.8625         0
# 11  58.0  female  First  26.5500         1
# 23  28.0    male  First  35.5000         1

# %%
grouped2=df.groupby(['class', 'sex'])
grouped2

# %%
grouped2.mean()
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
grouped2.mean().loc['First']
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
grouped2.mean().loc[('First', 'female')]
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %%
grouped2.mean().xs('male', level='sex')
# Out:
#               age       fare  survived
# class
# First   41.281386  67.226127  0.368852
# Second  30.740707  19.741782  0.157407
# Third   26.507589  12.661633  0.135447

# %%
grouped2.mean().xs('First', level='class')
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
pd.set_option('display.max_columns',10)
pd.set_option('display.max_colwidth',20)

# %%
df=titanic.loc[:,['age','sex','class','fare','survived']]
print(df.head())
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
df1=pd.pivot_table(df.
                  index='class',
                  columns='sex',
                  valus='age',
                  aggfunc='mean')
df1
# Out:
#   File "<ipython-input-69-50962df5fb62>", line 1
#     df1=pd.pivot_table(df.
#                        ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
df2=pd.pivot_table(df,
                  index='class',
                  columns='sex',
                  values='survived',
                  aggfunc=['mean','sum'])
df2
# Out:
#             mean              sum
# sex       female      male female male
# class
# First   0.968085  0.368852     91   45
# Second  0.921053  0.157407     70   17
# Third   0.500000  0.135447     72   47

# %%
df3=pd.pivot_table(df,
                  index=['class','sex'],
                  columns='sex',
                  values=['age','fare'],
                  aggfunc=['fare', 'survived'])
df3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-eee587806e18> in <module>
# ----> 1 df3=pd.pivot_table(df,
#       2                   index=['class','sex'],
#       3                   columns='sex',
#       4                   values=['age','fare'],
#       5                   aggfunc=['fare', 'survived'])
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      56         keys = []
#      57         for func in aggfunc:
# ---> 58             table = pivot_table(
#      59                 data,
#      60                 values=values,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     132
#     133     # GH17038, this check should only happen if index is defined (not None)
# --> 134     if table.index.nlevels > 1 and index:
#     135         # Related GH #17123
#     136         # If index_names are integers, determine whether the integers refer
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'index'

# %%
pdf3 = pd.pivot_table(df,                       # 피벗할 데이터프레임
                     index=['class', 'sex'],    # 행 위치에 들어갈 열
                     columns='survived',        # 열 위치에 들어갈 열
                     values=['age', 'fare'],    # 데이터로 사용할 열
                     aggfunc=['mean', 'max'])
pdf3
# Out:
#                     mean                                      max        \
#                      age                   fare               age
# survived               0          1           0           1     0     1
# class  sex
# First  female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# Second female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# Third  female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#        male    27.255814  22.274211   12.204469   15.579696  74.0  45.0
#
#
#                  fare
# survived            0         1
# class  sex
# First  female  151.55  512.3292
#        male    263.00  512.3292
# Second female   26.00   65.0000
#        male     73.50   39.0000
# Third  female   69.55   31.3875
#        male     69.55   56.4958

# %%
df3xs(('First','female'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-db28d584a1a5> in <module>
# ----> 1 df3,xs(('First','female'))
#
# NameError: name 'df3' is not defined

# %%
df3.xs(('mean',axis=1))

# %%
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name'] 

# 데이터 살펴보기
print(df.head())   
print('\n')

#  IPython 디스플레이 설정 - 출력할 열의 개수 한도 늘리기
pd.set_option('display.max_columns', 10)
print(df.head())   
print('\n')
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino
#
#
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino

# %%
df=pd.read_csv('./auto-mpg.csv', header=None)

df.columns=['mpg', 'cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']
print(df.head())
print('\n')

pd.set_option('display.max_columns',10)
print(df.head())
print('\n')
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino
#
#
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino

# %%
print(df.describe())
print('\n')
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df = pd.read_csv('./auto-mpg.csv', header=None)

# 열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name'] 

# 데이터 살펴보기
print(df.head())   
print('\n')

#  IPython 디스플레이 설정 - 출력할 열의 개수 한도 늘리기
pd.set_option('display.max_columns', 10)
print(df.head())   
print('\n')


'''
[Step 2] 데이터 탐색
'''

# 데이터 자료형 확인
print(df.info())  
print('\n')

# 데이터 통계 요약정보 확인
print(df.describe())
print('\n')

# horsepower 열의 자료형 변경 (문자열 ->숫자)
print(df['horsepower'].unique())          # horsepower 열의 고유값 확인
print('\n')

df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환

print(df.describe())                                     # 데이터 통계 요약정보 확인
print('\n')


'''
[Step 3] 속성(feature 또는 variable) 선택
'''

# 분석에 활용할 열(속성)을 선택 (연비, 실린더, 출력, 중량)
ndf = df[['mpg', 'cylinders', 'horsepower', 'weight']]
print(ndf.head())   
print('\n')
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino
#
#
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                 name
# 0       1  chevrolet chevel...
# 1       1    buick skylark 320
# 2       1   plymouth satellite
# 3       1        amc rebel sst
# 4       1          ford torino
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None
#
#
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
#
#
# ['130.0' '165.0' '150.0' '140.0' '198.0' '220.0' '215.0' '225.0' '190.0'
#  '170.0' '160.0' '95.00' '97.00' '85.00' '88.00' '46.00' '87.00' '90.00'
#  '113.0' '200.0' '210.0' '193.0' '?' '100.0' '105.0' '175.0' '153.0'
#  '180.0' '110.0' '72.00' '86.00' '70.00' '76.00' '65.00' '69.00' '60.00'
#  '80.00' '54.00' '208.0' '155.0' '112.0' '92.00' '145.0' '137.0' '158.0'
#  '167.0' '94.00' '107.0' '230.0' '49.00' '75.00' '91.00' '122.0' '67.00'
#  '83.00' '78.00' '52.00' '61.00' '93.00' '148.0' '129.0' '96.00' '71.00'
#  '98.00' '115.0' '53.00' '81.00' '79.00' '120.0' '152.0' '102.0' '108.0'
#  '68.00' '58.00' '149.0' '89.00' '63.00' '48.00' '66.00' '139.0' '103.0'
#  '125.0' '133.0' '138.0' '135.0' '142.0' '77.00' '62.00' '132.0' '84.00'
#  '64.00' '74.00' '116.0' '82.00']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-7b092b955140> in <module>
#      31 print('\n')
#      32
# ---> 33 df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
#      34 df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
#      35 df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환
#
# NameError: name 'np' is not defined

# %%
df['horsepower']=replace('?', np.nan, inplace=True)
df.horsepower
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-3d50bee236b9> in <module>
# ----> 1 df['horsepower']=replace('?', np.nan, inplace=True)
#       2 df.horsepower
#
# NameError: name 'replace' is not defined

# %%
ndf = df[['mpg', 'cylinders', 'horsepower', 'weight']]
print(ndf.head())   
print('\n')
# Out:
#     mpg  cylinders horsepower  weight
# 0  18.0          8      130.0  3504.0
# 1  15.0          8      165.0  3693.0
# 2  18.0          8      150.0  3436.0
# 3  16.0          8      150.0  3433.0
# 4  17.0          8      140.0  3449.0

# %%
ndf.plot(kind='scatter', x='weight', y='mpg',c='coral',s=10, figsize=(10, 5))
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-1ebe93723018> in <module>
#       1 ndf.plot(kind='scatter', x='weight', y='mpg',c='coral',s=10, figsize=(10, 5))
# ----> 2 plt.show()
#       3 plt.close()
#
# NameError: name 'plt' is not defined

# %%
fig=plt.figure(figsize=(10,5))
ax1=fig.add_subplot(1,2,1)
ax2=fig.add_subplot(1,2,2)

sns.regplot(x='weight', y='mpg', data=ndf, ax=ax1)
sns.regplot(x='weight', y='mpg', data=ndf, ax=ax2, figt_reg=False)
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-71222f339170> in <module>
# ----> 1 fig=plt.figure(figsize=(10,5))
#       2 ax1=fig.add_subplot(1,2,1)
#       3 ax2=fig.add_subplot(1,2,2)
#       4
#       5 sns.regplot(x='weight', y='mpg', data=ndf, ax=ax1)
#
# NameError: name 'plt' is not defined

# %%
fig = plt.figure(figsize=(10, 5))   
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
sns.regplot(x='weight', y='mpg', data=ndf, ax=ax1)                 # 회귀선 표시
sns.regplot(x='weight', y='mpg', data=ndf, ax=ax2, fit_reg=False)  #회귀선 미표시
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-f545caa43d24> in <module>
# ----> 1 fig = plt.figure(figsize=(10, 5))
#       2 ax1 = fig.add_subplot(1, 2, 1)
#       3 ax2 = fig.add_subplot(1, 2, 2)
#       4 sns.regplot(x='weight', y='mpg', data=ndf, ax=ax1)                 # 회귀선 표시
#       5 sns.regplot(x='weight', y='mpg', data=ndf, ax=ax2, fit_reg=False)  #회귀선 미표시
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(x='weight', y='mpg', data=ndf)              # 회귀선 없음
sns.jointplot(x='weight', y='mpg', kind='reg', data=ndf)  # 회귀선 표시
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-9f851df97e91> in <module>
#       1 sns.jointplot(x='weight', y='mpg', data=ndf)              # 회귀선 없음
#       2 sns.jointplot(x='weight', y='mpg', kind='reg', data=ndf)  # 회귀선 표시
# ----> 3 plt.show()
#       4 plt.close()
#
# NameError: name 'plt' is not defined

# %%
sns.pairplot(ndf)  
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-8a0402351919> in <module>
#       1 sns.pairplot(ndf)
# ----> 2 plt.show()
#       3 plt.close()
#
# NameError: name 'plt' is not defined

# %%
 from sklern.lineanr_model import LinearRegression
lr =  LinearRegression()
lr.fit(X_train, y_train)
r_square = lr.score(X_test, y_test)
print(r_square)
print('\n')

print('기울기 a : ', lr.coef_)
print('\n')
print('y절편 b', lr.intercept_)

y_hat = lr.predict(X)

plt.figure(figsize=(10, 5))
ax1 = sns.distplot(y, hist=False, label="y")
ax2 = sns.distplot(y_hat, hist=False, label="y_hat", ax=ax1)
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-98-62e21dd7f266> in <module>
# ----> 1 from sklern.lineanr_model import LinearRegression
#       2 lr =  LinearRegression()
#       3 lr.fit(X_train, y_train)
#       4 r_square = lr.score(X_test, y_test)
#       5 print(r_square)
#
# ModuleNotFoundError: No module named 'sklern'

# %%
### 기본 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

'''
[Step 1 ~ 4] 데이터 준비 
'''
# CSV 파일을 데이터프레임으로 변환
df = pd.read_csv('./auto-mpg.csv', header=None)
df
# 열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name'] 

# horsepower 열의 자료형 변경 (문자열 ->숫자)
df['horsepower'].replace('?', np.nan, inplace=True)      # '?'을 np.nan으로 변경
df.dropna(subset=['horsepower'], axis=0, inplace=True)   # 누락데이터 행을 삭제
df['horsepower'] = df['horsepower'].astype('float')      # 문자열을 실수형으로 변환

# 분석에 활용할 열(속성)을 선택 (연비, 실린더, 출력, 중량)
ndf = df[['mpg', 'cylinders', 'horsepower', 'weight']]

# ndf 데이터를 train data 와 test data로 구분(7:3 비율)
X=ndf[['weight']]  #독립 변수 X
y=ndf['mpg']     #종속 변수 Y

# train data 와 test data로 구분(7:3 비율)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

print('훈련 데이터 : ', X_train.shape)
print('검증 데이터 : ', X_test.shape)
# Out:
# 훈련 데이터 :  (274, 1)
# 검증 데이터 :  (118, 1)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
# -*- coding: utf-8 -*-

### 기본 라이브러리 불러오기
import pandas as pd
import seaborn as sns

'''
[Step 1] 데이터 준비 - Seaborn에서 제공하는 titanic 데이터셋 가져오기
'''

# load_dataset 함수를 사용하여 데이터프레임으로 변환
df = sns.load_dataset('titanic')

# 데이터 살펴보기
print(df.head())   
print('\n')

#  IPython 디스플레이 설정 - 출력할 열의 개수 한도 늘리기
pd.set_option('display.max_columns', 15)
print(df.head())   
print('\n')
# Out:
#    survived  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town  \
# 0         0       3    male  22.0      1  ...        True   NaN  Southampton
# 1         1       1  female  38.0      1  ...       False     C    Cherbourg
# 2         1       3  female  26.0      0  ...       False   NaN  Southampton
# 3         1       1  female  35.0      1  ...       False     C  Southampton
# 4         0       3    male  35.0      0  ...        True   NaN  Southampton
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True
# 3   yes  False
# 4    no   True
#
# [5 rows x 15 columns]
#
#
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
rdf.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-4fd10a90abd1> in <module>
# ----> 1 rdf.head(50)
#
# NameError: name 'rdf' is not defined
