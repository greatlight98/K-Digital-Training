# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
import cv2
# img = cv2.imread('c:/webcam/cam_DL_opencv/cat.bmp')

cap = cv2.VideoCapture(0)


if not cap.isOpened():
    print('camera open failed')
    sys.exit()

cv2.namedWindow('image')
cv2.namedWindow('image_edge')

fourcc = cv2.VideoWriter_fourcc(*'DIVX') # fourcc 값 받아오기
fps = 30

w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

out = cv2.VideoWriter('c:/webcam/cam_DL_opencv/output1.avi', fourcc, fps, (w, h), isColor = True)

while True: # 무한 루프
    ret, frame = cap.read() # 카메라의 ret, frame 값 받아오기
    if not ret: #ret이 False면 중지
        break
        

    #### 작업 구간
    
    edge = cv2.Canny(frame, 50,150)# 윤곽선
    inversed = ~frame # 반전
    edge_color = cv2.cvtColor(edge, cv2.COLOR_GRAY2BGR) #컬러 영상으로 변경
        
    cv2.imshow('image', frame)
    cv2.imshow('image_edge', edge)
    # cv2.imshow('image_inverse', inversed)
    
    #out.write(frame)
    out.write(edge_color) # 영상 데이터만 저장
   
    #####
    
    
    if cv2.waitKey(10) == 27:
        break
out.release()    
cap.release()    
cv2.destroyAllWindows()

###########################


cap = cv2.VideoCapture('c:/webcam/cam_DL_opencv/output1.avi')
rc = cv2.selectROI('frame', frame)
# 초깃값 설정
tracker.init(frame, rc)

# 매 프레임 처리
while True:
    ret, frame = cap.read()

    if not ret:
        print('Frame read failed!')
        sys.exit()

    # 추척 $ ROI 사각형 업데이트
    # 매 프래임마다 update하고 rc값 받아옴
    ret, rc = tracker.update(frame)
    
    # floate 형태로 rc값을 받으므로 int로 변환해서 list로 감싸고 tuple로 변환
    rc = tuple([int(_) for _ in rc])
    cv2.rectangle(frame, rc, (0, 0, 255), 2)
    
    cv2.imshow('frame', frame)
    if cv2.waitKey(20) == 27:
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-faae107a5c04> in <module>
#      58 rc = cv2.selectROI('frame', frame)
#      59 # 초깃값 설정
# ---> 60 tracker.init(frame, rc)
#      61
#      62 # 매 프레임 처리
#
# NameError: name 'tracker' is not defined
