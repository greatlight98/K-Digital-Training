# %% [markdown]
# Reshaping Data
#
# sort_values
# 특정 열의 데이터를 기준으로 데이터프레임을 정렬함
#
# df.rename
# 데이터프레임 내의 행, 열의 이름을 변경함
#
# df.sort_index
# index별로 정렬함
#
# df.reset_index
# index가 없을 때, Index를 생성해서 정렬함.
#
#
# 데이터 재형성

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("mpg")

df.shape
# Out:
# (398, 9)

# %% [markdown]
# (데이터 368개, 속성9개)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# sort_values
# 특정 열의 데이터를 기준으로 데이터프레임을 정렬함

# %%
df.sort_values?

# %%
df.sort_values('mpg').head() 
#mpg의 작은값 부터 큰 값으로 정렬 - 특정 열 지정으로 그 열 기준으로 정렬됨
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28    9.0          8         304.0       193.0    4732          18.5
# 25   10.0          8         360.0       215.0    4615          14.0
# 26   10.0          8         307.0       200.0    4376          15.0
# 103  11.0          8         400.0       150.0    4997          14.0
# 124  11.0          8         350.0       180.0    3664          11.0
#
#      model_year origin              name
# 28           70    usa          hi 1200d
# 25           70    usa         ford f250
# 26           70    usa         chevy c20
# 103          73    usa  chevrolet impala
# 124          73    usa  oldsmobile omega

# %%
df.sort_values('cylinders').head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
#
#      model_year origin             name
# 111          73  japan        maxda rx3
# 71           72  japan  mazda rx2 coupe
# 334          80  japan    mazda rx-7 gs
# 243          77  japan       mazda rx-4
# 267          78  japan    toyota corona

# %%
df.sort_values('mpg', ascending = False).head() 
#ascending = False : 역순 정렬
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 325  44.3          4          90.0        48.0    2085          21.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 326  43.4          4          90.0        48.0    2335          23.7
#
#      model_year  origin                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)

# %%
df.rename(columns={'model_year':'year'}).head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df.head() 
#원본데이터 지키는게 기본값이라 위 코딩내용이 적용 안되어 있음
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df2=df.drop(columns=['mpg']) #선택 데이터 빼기
df2.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin                       name
# 0    usa  chevrolet chevelle malibu
# 1    usa          buick skylark 320
# 2    usa         plymouth satellite
# 3    usa              amc rebel sst
# 4    usa                ford torino

# %%
df3=df.drop(columns=['mpg','name'])
df3.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0    3504          12.0          70
# 1          8         350.0       165.0    3693          11.5          70
# 2          8         318.0       150.0    3436          11.0          70
# 3          8         304.0       150.0    3433          12.0          70
# 4          8         302.0       140.0    3449          10.5          70
#
#   origin
# 0    usa
# 1    usa
# 2    usa
# 3    usa
# 4    usa

# %% [markdown]
# 2. 깔끔한 데이터 만들기 (melo, pivot)
# pd.melt (열 값을 모아서 행으로 변경)

# %%
pd.melt?

# %%
df=pd.DataFrame({'A': {0:'a', 1:'b', 2:'c'},
                'B': {0:1, 1:3, 2:5},
                'C': {0:2, 1:4, 2:6}})
df
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
pd.melt(df, id_vars=['A'], value_vars=['B'])
# Out:
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5

# %%
df2=pd.melt(df, value_vars=['A','B','C'])
df2
# Out:
#   variable value
# 0        A     a
# 1        A     b
# 2        A     c
# 3        B     1
# 4        B     3
# 5        B     5
# 6        C     2
# 7        C     4
# 8        C     6

# %% [markdown]
# method chaining

# %% [markdown]
# df.pivot
# 행의 값을 열의 값으로 변경

# %%
df.concat : 데이터프레임 합치기
# Out:
#   File "<ipython-input-29-b312d6dd7c49>", line 1
#     df.concat : 데이터프레임 합치기
#                        ^
# SyntaxError: invalid syntax

# %%
s1=pd.Series(['a','b'])
s1
# Out:
# 0    a
# 1    b
# dtype: object

# %%
s2=pd.Series(['c','d'])
s2
# Out:
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1, s2]) #s1과 s2합쳐짐
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
pd.concat([s1, s2]), keys=['s1',]
