# %%
import requests as rq
from bs4 import BeautifulSoup as bs

url = "https://github.com/search"

for i in range(0,5):
    req = rq.get(url + '?p=' + str(i) + '&q=Core+Developer&type=Repositories')
    soup = bs(req.text, 'html.parser')
    
print(soup.find('Core'))
my_anchor = soup.select('div > a')
for title in my_anchor:
    print(title.text)
    print(title.get('href'))
# Out:
# None
# Skip to content
# #start-of-content
#
#
#
# https://github.com/
#
#                 Sign up
#
# /signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Fsearch&source=header
# Features →
# /features
# Plans →
# /pricing
#
#             Sign in
#
# /login?return_to=%2Fsearch%3Fp%3D4%26q%3DCore%2BDeveloper%26type%3DRepositories
# Repositories984
# /search?q=Core+Developer&type=repositories
# Code
# /search?q=Core+Developer&type=code
# Commits
# /search?q=Core+Developer&type=commits
# Issues
# /search?q=Core+Developer&type=issues
# DiscussionsBeta
# /search?q=Core+Developer&type=discussions
# Packages
# /search?q=Core+Developer&type=registrypackages
# Marketplace
# /search?q=Core+Developer&type=marketplace
# Topics
# /search?q=Core+Developer&type=topics
# Wikis
# /search?q=Core+Developer&type=wikis
# Users
# /search?q=Core+Developer&type=users
# Advanced search
# /search/advanced?q=Core+Developer&type=Repositories
#
#
#
#
# Best match
#
# /search?o=desc&q=Core+Developer&s=&type=Repositories
#
#
#
#
# Most stars
#
# /search?o=desc&q=Core+Developer&s=stars&type=Repositories
#
#
#
#
# Fewest stars
#
# /search?o=asc&q=Core+Developer&s=stars&type=Repositories
#
#
#
#
# Most forks
#
# /search?o=desc&q=Core+Developer&s=forks&type=Repositories
#
#
#
#
# Fewest forks
#
# /search?o=asc&q=Core+Developer&s=forks&type=Repositories
#
#
#
#
# Recently updated
#
# /search?o=desc&q=Core+Developer&s=updated&type=Repositories
#
#
#
#
# Least recently updated
#
# /search?o=asc&q=Core+Developer&s=updated&type=Repositories
# americanexpress/amex-api-java-client-core
# /americanexpress/amex-api-java-client-core
#
#   api
#
# /topics/api
#
#   authentication
#
# /topics/authentication
#
#   amex
#
# /topics/amex
#
#   amex-for-developers
#
# /topics/amex-for-developers
#
#
#
#
#               20
#
# /americanexpress/amex-api-java-client-core/stargazers
# Origen-SDK/origen
# /Origen-SDK/origen
#
#               3 issues
#               need help
#
# /Origen-SDK/origen/issues?q=label%3A%22help+wanted%22+is%3Aissue+is%3Aopen
#
#
#
#
#               16
#
# /Origen-SDK/origen/stargazers
# spring-projects/spring-data-elasticsearch
# /spring-projects/spring-data-elasticsearch
#
#
#
#
#               2.5k
#
# /spring-projects/spring-data-elasticsearch/stargazers
# AlenToma/EntityWorker.Core
# /AlenToma/EntityWorker.Core
#
#   orm
#
# /topics/orm
#
#   database
#
# /topics/database
#
#   sqlite
#
# /topics/sqlite
#
#   postgresql
#
# /topics/postgresql
#
#   entity-framework
#
# /topics/entity-framework
#
#   sqlclient
#
# /topics/sqlclient
#
#
#
#
#               92
#
# /AlenToma/EntityWorker.Core/stargazers
# vmware-archive/simple-k8s-test-env
# /vmware-archive/simple-k8s-test-env
#
#
#
#
#               56
#
# /vmware-archive/simple-k8s-test-env/stargazers
# spring-projects/spring-data-redis
# /spring-projects/spring-data-redis
#
#   java
#
# /topics/java
#
#   redis
#
# /topics/redis
#
#   framework
#
# /topics/framework
#
#   spring
#
# /topics/spring
#
#   spring-data
#
# /topics/spring-data
#
#   ddd
#
# /topics/ddd
#
#
#
#
#               1.3k
#
# /spring-projects/spring-data-redis/stargazers
# spring-projects/spring-data-mongodb
# /spring-projects/spring-data-mongodb
#
#   java
#
# /topics/java
#
#   framework
#
# /topics/framework
#
#   spring
#
# /topics/spring
#
#   mongodb
#
# /topics/mongodb
#
#   spring-data
#
# /topics/spring-data
#
#   ddd
#
# /topics/ddd
#
#
#
#
#               1.3k
#
# /spring-projects/spring-data-mongodb/stargazers
# doocs/advanced-java
# /doocs/advanced-java
#
#   redis
#
# /topics/redis
#
#   zookeeper
#
# /topics/zookeeper
#
#   java
#
# /topics/java
#
#   elasticsearch
#
# /topics/elasticsearch
#
#   distributed-systems
#
# /topics/distributed-systems
#
#   spring-cloud
#
# /topics/spring-cloud
#
#   rpc
#
# /topics/rpc
#
#   message-queue
#
# /topics/message-queue
#
#   high-availability
#
# /topics/high-availability
#
#   hystrix
#
# /topics/hystrix
#
#   ribbon
#
# /topics/ribbon
#
#   eureka
#
# /topics/eureka
#
#   microservices-architecture
#
# /topics/microservices-architecture
#
#   feign
#
# /topics/feign
#
#   high-concurrency
#
# /topics/high-concurrency
#
#   dubbo
#
# /topics/dubbo
#
#   advanced-java
#
# /topics/advanced-java
#
#   distributed-search-engine
#
# /topics/distributed-search-engine
#
#   springcloud-config
#
# /topics/springcloud-config
#
#   doocs
#
# /topics/doocs
#
#
#
#
#               55.9k
#
# /doocs/advanced-java/stargazers
# pndaproject/red-pnda
# /pndaproject/red-pnda
#
#
#
#
#               24
#
# /pndaproject/red-pnda/stargazers
# Office365DevOps/dotnetcore-office365dev-templates-msgraph
# /Office365DevOps/dotnetcore-office365dev-templates-msgraph
#
#   dotnetcore
#
# /topics/dotnetcore
#
#   dotnet-core
#
# /topics/dotnet-core
#
#   office365
#
# /topics/office365
#
#   office-365
#
# /topics/office-365
#
#   microsoft-graph
#
# /topics/microsoft-graph
#
#
#
#
#               30
#
# /Office365DevOps/dotnetcore-office365dev-templates-msgraph/stargazers
# Previous
# /search?p=3&q=Core+Developer&type=Repositories
# 1
# /search?p=1&q=Core+Developer&type=Repositories
# 2
# /search?p=2&q=Core+Developer&type=Repositories
# 3
# /search?p=3&q=Core+Developer&type=Repositories
# 5
# /search?p=5&q=Core+Developer&type=Repositories
# 6
# /search?p=6&q=Core+Developer&type=Repositories
# 98
# /search?p=98&q=Core+Developer&type=Repositories
# 99
# /search?p=99&q=Core+Developer&type=Repositories
# Next
# /search?p=5&q=Core+Developer&type=Repositories
# Advanced search
# /search/advanced?q=Core+Developer
#
#
#
#
#
# https://github.com
